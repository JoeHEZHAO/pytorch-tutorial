# %%
from cifar10_dataloader import CIFAR10

c10 = CIFAR10()
c10.imshow()
# Out:
# /home/dyj/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# ...
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-2-a3995dc42d28> in <module>()
#       1 from cifar10_dataloader import CIFAR10
#       2
# ----> 3 c10 = CIFAR10()
#       4 c10.imshow()
#
# /home/dyj/workspace/pytorch-exercise/cifar10_dataloader.py in __init__(self)
#      17
#      18     self.classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# ---> 19     self._trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=self.transform)
#      20     self._trainloader = torch.utils.data.DataLoader(self._trainset, batch_size=4, shuffle=True, num_workers=2)
# ...
